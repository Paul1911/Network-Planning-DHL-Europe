# %% [markdown]
# With this file I pulled the distances of the ca. 30000 airport combinations. As the API only allowed up to 10000 requests per day at the time, I had to complete it part by part.

# %%
import csv
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyAYOvbNCRiG20a8sUcDekArNQu1zBSba3M ')

inp = open ('C:\ZZ_AP2\AP2\DataForMapsP3.csv','r')
outp = open ('C:\ZZ_AP2\AP2\DistancesP3.csv','w', newline='')

reader = csv.reader(inp)
writer = csv.writer(outp)

for row in list(reader)[1:]:
    writer.writerow((row[0],row[1],row[4],distance['rows'][0]['elements'][0]['distance']['value']))
    print((row[0],row[1],row[4],distance['rows'][0]['elements'][0]['distance']['value']))
inp.close()
outp.close()

print('Finished')
# Out:
# ('BGOGIB', 'BGO', 'GIB', 3914017)
# ('BGOGLA', 'BGO', 'GLA', 2692271)
# ('BGOGOA', 'BGO', 'GOA', 2368462)
# ('BGOGOT', 'BGO', 'GOT', 778851)
# ('BGOGRX', 'BGO', 'GRX', 3672790)
# ('BGOGRZ', 'BGO', 'GRZ', 2218233)
# ('BGOGVA', 'BGO', 'GVA', 2170116)
# ('BGOHAJ', 'BGO', 'HAJ', 1253572)
# ('BGOHAM', 'BGO', 'HAM', 1102534)
# ('BGOHEL', 'BGO', 'HEL', 1455532)
# ('BGOIBZ', 'BGO', 'IBZ', 3442122)
# ('BGOINI', 'BGO', 'INI', 2861505)
# ('BGOIST', 'BGO', 'IST', 3571228)
# ('BGOKIR', 'BGO', 'KIR', 2931490)
# ('BGOKLU', 'BGO', 'KLU', 2253567)
# ('BGOKRK', 'BGO', 'KRK', 1969528)
# ('BGOKRS', 'BGO', 'KRS', 469214)
# ('BGOKTW', 'BGO', 'KTW', 1927455)
# ('BGOKVB', 'BGO', 'KVB', 822380)
# ('BGOLBA', 'BGO', 'LBA', 2363146)
# ('BGOLCA', 'BGO', 'LCA', 4646741)
# ('BGOLCG', 'BGO', 'LCG', 3438848)
# ('BGOLDE', 'BGO', 'LDE', 2816932)
# ('BGOLEJ', 'BGO', 'LEJ', 1489926)
# ('BGOLGG', 'BGO', 'LGG', 1635186)
# ('BGOLIL', 'BGO', 'LIL', 1786392)
# ('BGOLIS', 'BGO', 'LIS', 3714921)
# ...
